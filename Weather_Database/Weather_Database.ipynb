# %% [markdown]
# # Generate Random Cities

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# %%
# Create a set of random latitude and longitude combos
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# hold the lats and longs into a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique then we add to cities list
    if city not in cities:
        cities.append(city)

# Print city count to confirm number
len(cities)
# Out:
# 770

# %% [markdown]
# # Pulling Data on Cities with API

# %%
# Import requests and weather_api_key
import requests 
from config_2 import vacation_api_key

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&lat={lat}&lon={lon}&appid=" + vacation_api_key

# %%
# Declare empty list to hold weather data for each city
city_data = []

# Print the begining of the logging
print("Beggining Data Retrieval     ")
print("-----------------------------")

# Create counters to iterated the logging for each recorded response and the set to start at 1
record_count = 1
set_count = 1
# Out:
# Beggining Data Retrieval
# -----------------------------

# %%
# loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each City
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print(f"{city} not found, skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | gornopravdinsk
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | barra do garcas
# Processing Record 6 of Set 1 | sao filipe
# Processing Record 7 of Set 1 | broome
# Processing Record 8 of Set 1 | rio grande
# Processing Record 9 of Set 1 | kahului
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | itarema
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | tikhvin
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | canico
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | shagonar
# Processing Record 18 of Set 1 | sao gabriel da cachoeira
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | hovd
# Processing Record 21 of Set 1 | macau
# Processing Record 22 of Set 1 | miechow
# Processing Record 23 of Set 1 | aksarka
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | kokoda
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | kumano
# Processing Record 29 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found, skipping...
# Processing Record 30 of Set 1 | puerto del rosario
# Processing Record 31 of Set 1 | manzhouli
# Processing Record 32 of Set 1 | ulaanbaatar
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | graaff-reinet
# Processing Record 36 of Set 1 | sarakhs
# Processing Record 37 of Set 1 | hobyo
# Processing Record 38 of Set 1 | tomatlan
# Processing Record 39 of Set 1 | leh
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | waipawa
# Processing Record 42 of Set 1 | cootamundra
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | akdepe
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | leshukonskoye
# Processing Record 49 of Set 1 | vila franca do campo
# Processing Record 50 of Set 1 | saint-pierre
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | riyadh
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | barentsburg
# barentsburg not found, skipping...
# Processing Record 6 of Set 2 | odoyev
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | kuche
# kuche not found, skipping...
# Processing Record 9 of Set 2 | roald
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | ust-kan
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | ambon
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | mana
# Processing Record 20 of Set 2 | ondjiva
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | labuhan
# Processing Record 23 of Set 2 | ayan
# Processing Record 24 of Set 2 | basoko
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | port-cartier
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | conde
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | nantucket
# Processing Record 32 of Set 2 | praya
# Processing Record 33 of Set 2 | killarney
# Processing Record 34 of Set 2 | tsihombe
# tsihombe not found, skipping...
# Processing Record 35 of Set 2 | alekseyevsk
# Processing Record 36 of Set 2 | taolanaro
# taolanaro not found, skipping...
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | samusu
# samusu not found, skipping...
# Processing Record 39 of Set 2 | jabinyanah
# Processing Record 40 of Set 2 | karratha
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | skibbereen
# Processing Record 44 of Set 2 | ornskoldsvik
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | belyy yar
# Processing Record 49 of Set 2 | paihia
# Processing Record 50 of Set 2 | samarai
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | avera
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | saint augustine
# Processing Record 5 of Set 3 | mys shmidta
# mys shmidta not found, skipping...
# Processing Record 6 of Set 3 | ulladulla
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | solhan
# Processing Record 9 of Set 3 | amderma
# amderma not found, skipping...
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | xichang
# Processing Record 14 of Set 3 | atambua
# Processing Record 15 of Set 3 | ahuimanu
# Processing Record 16 of Set 3 | lethem
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | port hueneme
# Processing Record 19 of Set 3 | neuquen
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | ostrovnoy
# Processing Record 22 of Set 3 | breves
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | ca mau
# Processing Record 25 of Set 3 | lazaro cardenas
# Processing Record 26 of Set 3 | lompoc
# Processing Record 27 of Set 3 | belushya guba
# belushya guba not found, skipping...
# Processing Record 28 of Set 3 | den helder
# Processing Record 29 of Set 3 | chernyshevskiy
# Processing Record 30 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | kaeo
# Processing Record 33 of Set 3 | xingcheng
# Processing Record 34 of Set 3 | chagda
# chagda not found, skipping...
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | lagos
# Processing Record 38 of Set 3 | jadu
# Processing Record 39 of Set 3 | mocuba
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | imbituba
# Processing Record 42 of Set 3 | las vegas
# Processing Record 43 of Set 3 | biak
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | zyryanka
# Processing Record 48 of Set 3 | solnechnyy
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | dire dawa
# Processing Record 2 of Set 4 | caucaia
# Processing Record 3 of Set 4 | port hedland
# Processing Record 4 of Set 4 | semey
# Processing Record 5 of Set 4 | bambanglipuro
# Processing Record 6 of Set 4 | bulgan
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | porto novo
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | luderitz
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | shingu
# Processing Record 13 of Set 4 | tigil
# Processing Record 14 of Set 4 | gazli
# Processing Record 15 of Set 4 | bathsheba
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | taltal
# Processing Record 18 of Set 4 | nguiu
# nguiu not found, skipping...
# Processing Record 19 of Set 4 | la rioja
# Processing Record 20 of Set 4 | dryden
# Processing Record 21 of Set 4 | beringovskiy
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | ust-uda
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | samalaeulu
# samalaeulu not found, skipping...
# Processing Record 29 of Set 4 | san pedro
# Processing Record 30 of Set 4 | bud
# Processing Record 31 of Set 4 | gengenbach
# Processing Record 32 of Set 4 | esmeralda
# Processing Record 33 of Set 4 | mamakan
# Processing Record 34 of Set 4 | mount pleasant
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | half moon bay
# Processing Record 37 of Set 4 | cranbrook
# Processing Record 38 of Set 4 | kjollefjord
# Processing Record 39 of Set 4 | arman
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | peniche
# Processing Record 42 of Set 4 | sinnamary
# Processing Record 43 of Set 4 | paragould
# Processing Record 44 of Set 4 | altayskoye
# Processing Record 45 of Set 4 | garowe
# Processing Record 46 of Set 4 | antofagasta
# Processing Record 47 of Set 4 | singkang
# Processing Record 48 of Set 4 | maragogi
# Processing Record 49 of Set 4 | ixtapa
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | longlac
# longlac not found, skipping...
# Processing Record 2 of Set 5 | camacari
# Processing Record 3 of Set 5 | batagay
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | busayra
# Processing Record 6 of Set 5 | miragoane
# Processing Record 7 of Set 5 | hwange
# Processing Record 8 of Set 5 | saint-joseph
# Processing Record 9 of Set 5 | bakel
# Processing Record 10 of Set 5 | dombarovskiy
# Processing Record 11 of Set 5 | saryshagan
# saryshagan not found, skipping...
# Processing Record 12 of Set 5 | hun
# Processing Record 13 of Set 5 | coahuayana
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | ulaangom
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | miraflores
# Processing Record 18 of Set 5 | nizhneyansk
# nizhneyansk not found, skipping...
# Processing Record 19 of Set 5 | otradnoye
# Processing Record 20 of Set 5 | igarka
# Processing Record 21 of Set 5 | urucara
# Processing Record 22 of Set 5 | baykit
# Processing Record 23 of Set 5 | avarua
# Processing Record 24 of Set 5 | toliary
# toliary not found, skipping...
# Processing Record 25 of Set 5 | omboue
# Processing Record 26 of Set 5 | barbastro
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | savannah bight
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | ust-kulom
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | ati
# Processing Record 33 of Set 5 | santa isabel do rio negro
# Processing Record 34 of Set 5 | izhmorskiy
# Processing Record 35 of Set 5 | palabuhanratu
# palabuhanratu not found, skipping...
# Processing Record 36 of Set 5 | matara
# Processing Record 37 of Set 5 | camapua
# Processing Record 38 of Set 5 | athabasca
# Processing Record 39 of Set 5 | haines junction
# Processing Record 40 of Set 5 | prince rupert
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | tuktoyaktuk
# Processing Record 44 of Set 5 | ngunguru
# Processing Record 45 of Set 5 | tarrafal
# Processing Record 46 of Set 5 | palmer
# Processing Record 47 of Set 5 | sakakah
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | urumqi
# Processing Record 50 of Set 5 | vaitupu
# vaitupu not found, skipping...
# Processing Record 1 of Set 6 | duobao
# Processing Record 2 of Set 6 | poya
# Processing Record 3 of Set 6 | puerto escondido
# Processing Record 4 of Set 6 | mixtepec
# mixtepec not found, skipping...
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | thinadhoo
# Processing Record 7 of Set 6 | mogadishu
# Processing Record 8 of Set 6 | greystones
# Processing Record 9 of Set 6 | medea
# Processing Record 10 of Set 6 | edinburg
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | mattru
# Processing Record 13 of Set 6 | vanavara
# Processing Record 14 of Set 6 | tornio
# Processing Record 15 of Set 6 | upernavik
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | celestun
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | georgiyevka
# Processing Record 20 of Set 6 | verkhnyaya inta
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | anadyr
# Processing Record 23 of Set 6 | bambous virieux
# Processing Record 24 of Set 6 | sol-iletsk
# Processing Record 25 of Set 6 | praia da vitoria
# Processing Record 26 of Set 6 | am timan
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | andapa
# Processing Record 29 of Set 6 | daru
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | manggar
# Processing Record 32 of Set 6 | sao francisco do sul
# Processing Record 33 of Set 6 | pachino
# Processing Record 34 of Set 6 | komsomolskiy
# Processing Record 35 of Set 6 | sentyabrskiy
# sentyabrskiy not found, skipping...
# Processing Record 36 of Set 6 | tres arroyos
# Processing Record 37 of Set 6 | pemangkat
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | itaituba
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | sitka
# Processing Record 42 of Set 6 | olafsvik
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | flinders
# Processing Record 45 of Set 6 | kavaratti
# Processing Record 46 of Set 6 | nelson bay
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | bilibino
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | port elizabeth
# Processing Record 1 of Set 7 | longyearbyen
# Processing Record 2 of Set 7 | udachnyy
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | trelew
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | oranjemund
# Processing Record 10 of Set 7 | peleduy
# Processing Record 11 of Set 7 | dingle
# Processing Record 12 of Set 7 | jiaojiang
# Processing Record 13 of Set 7 | arlit
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | homer
# Processing Record 16 of Set 7 | cherskiy
# Processing Record 17 of Set 7 | menongue
# Processing Record 18 of Set 7 | starachowice
# Processing Record 19 of Set 7 | nizwa
# Processing Record 20 of Set 7 | kamaishi
# Processing Record 21 of Set 7 | sanaur
# Processing Record 22 of Set 7 | teahupoo
# Processing Record 23 of Set 7 | talca
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | mantua
# Processing Record 26 of Set 7 | port hardy
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | lolua
# lolua not found, skipping...
# Processing Record 29 of Set 7 | pasinler
# Processing Record 30 of Set 7 | nola
# Processing Record 31 of Set 7 | chalon-sur-saone
# Processing Record 32 of Set 7 | mahon
# Processing Record 33 of Set 7 | general pico
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | uyuni
# Processing Record 36 of Set 7 | gazanjyk
# Processing Record 37 of Set 7 | marcona
# marcona not found, skipping...
# Processing Record 38 of Set 7 | murdochville
# Processing Record 39 of Set 7 | vrangel
# Processing Record 40 of Set 7 | senanga
# Processing Record 41 of Set 7 | teoloyucan
# Processing Record 42 of Set 7 | deputatskiy
# Processing Record 43 of Set 7 | khash
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | san jeronimo
# Processing Record 46 of Set 7 | san andres
# Processing Record 47 of Set 7 | nongan
# Processing Record 48 of Set 7 | kargalinskaya
# Processing Record 49 of Set 7 | tagusao
# Processing Record 50 of Set 7 | kachikau
# kachikau not found, skipping...
# Processing Record 1 of Set 8 | srednekolymsk
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | salihorsk
# Processing Record 5 of Set 8 | wenling
# Processing Record 6 of Set 8 | natal
# Processing Record 7 of Set 8 | abu samrah
# Processing Record 8 of Set 8 | ambovombe
# Processing Record 9 of Set 8 | kroya
# Processing Record 10 of Set 8 | castrillon
# Processing Record 11 of Set 8 | fasa
# Processing Record 12 of Set 8 | aquiraz
# Processing Record 13 of Set 8 | batesville
# Processing Record 14 of Set 8 | jaisalmer
# Processing Record 15 of Set 8 | thompson
# Processing Record 16 of Set 8 | warqla
# warqla not found, skipping...
# Processing Record 17 of Set 8 | mildura
# Processing Record 18 of Set 8 | sabaudia
# Processing Record 19 of Set 8 | acevedo
# Processing Record 20 of Set 8 | bonavista
# Processing Record 21 of Set 8 | sovetskiy
# Processing Record 22 of Set 8 | kodinar
# Processing Record 23 of Set 8 | tezu
# Processing Record 24 of Set 8 | bogovarovo
# Processing Record 25 of Set 8 | coihaique
# Processing Record 26 of Set 8 | manbij
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | shar
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | ipixuna
# Processing Record 31 of Set 8 | lasa
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | rameswaram
# Processing Record 34 of Set 8 | santa lucia
# Processing Record 35 of Set 8 | puerto ayacucho
# Processing Record 36 of Set 8 | amapa
# Processing Record 37 of Set 8 | svetlogorsk
# Processing Record 38 of Set 8 | barcelona
# Processing Record 39 of Set 8 | kamiiso
# Processing Record 40 of Set 8 | goundam
# Processing Record 41 of Set 8 | erenhot
# Processing Record 42 of Set 8 | osuna
# Processing Record 43 of Set 8 | shahrud
# Processing Record 44 of Set 8 | ancud
# Processing Record 45 of Set 8 | shambu
# Processing Record 46 of Set 8 | port arthur
# Processing Record 47 of Set 8 | lavrentiya
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | lorengau
# Processing Record 50 of Set 8 | greenock
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | kununurra
# Processing Record 3 of Set 9 | yatou
# Processing Record 4 of Set 9 | namtsy
# Processing Record 5 of Set 9 | siguiri
# Processing Record 6 of Set 9 | los llanos de aridane
# Processing Record 7 of Set 9 | lincoln
# Processing Record 8 of Set 9 | quatre cocos
# Processing Record 9 of Set 9 | yumen
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | safford
# Processing Record 12 of Set 9 | sartell
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | poso
# Processing Record 15 of Set 9 | khani
# Processing Record 16 of Set 9 | ulcinj
# Processing Record 17 of Set 9 | shenjiamen
# Processing Record 18 of Set 9 | mehran
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | victoria point
# Processing Record 21 of Set 9 | kailua
# Processing Record 22 of Set 9 | fairbanks
# Processing Record 23 of Set 9 | chateauroux
# Processing Record 24 of Set 9 | talara
# Processing Record 25 of Set 9 | kilindoni
# Processing Record 26 of Set 9 | tumaco
# Processing Record 27 of Set 9 | tarko-sale
# Processing Record 28 of Set 9 | tazmalt
# Processing Record 29 of Set 9 | ishigaki
# Processing Record 30 of Set 9 | wukari
# Processing Record 31 of Set 9 | tarakan
# Processing Record 32 of Set 9 | ranong
# Processing Record 33 of Set 9 | twin falls
# Processing Record 34 of Set 9 | liaoyang
# Processing Record 35 of Set 9 | alugan
# Processing Record 36 of Set 9 | huinan
# Processing Record 37 of Set 9 | presidencia roque saenz pena
# Processing Record 38 of Set 9 | sao benedito do rio preto
# Processing Record 39 of Set 9 | dunmore town
# Processing Record 40 of Set 9 | tessalit
# Processing Record 41 of Set 9 | bereslavka
# Processing Record 42 of Set 9 | machali
# Processing Record 43 of Set 9 | lumphat
# Processing Record 44 of Set 9 | bonnyville
# Processing Record 45 of Set 9 | grand gaube
# Processing Record 46 of Set 9 | utete
# Processing Record 47 of Set 9 | campoverde
# Processing Record 48 of Set 9 | kifri
# Processing Record 49 of Set 9 | ardakan
# Processing Record 50 of Set 9 | alyangula
# Processing Record 1 of Set 10 | northam
# Processing Record 2 of Set 10 | bowen
# Processing Record 3 of Set 10 | vestbygda
# vestbygda not found, skipping...
# Processing Record 4 of Set 10 | mitsamiouli
# Processing Record 5 of Set 10 | birjand
# Processing Record 6 of Set 10 | saraland
# Processing Record 7 of Set 10 | saravan
# Processing Record 8 of Set 10 | marsa matruh
# Processing Record 9 of Set 10 | crieff
# Processing Record 10 of Set 10 | kuytun
# Processing Record 11 of Set 10 | lavumisa
# Processing Record 12 of Set 10 | turayf
# Processing Record 13 of Set 10 | salalah
# Processing Record 14 of Set 10 | juneau
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | karakendzha
# karakendzha not found, skipping...
# Processing Record 17 of Set 10 | byron bay
# Processing Record 18 of Set 10 | talcahuano
# Processing Record 19 of Set 10 | meulaboh
# Processing Record 20 of Set 10 | abasolo
# Processing Record 21 of Set 10 | kabrai
# Processing Record 22 of Set 10 | derzhavinsk
# Processing Record 23 of Set 10 | abu jubayhah
# abu jubayhah not found, skipping...
# Processing Record 24 of Set 10 | betioky
# Processing Record 25 of Set 10 | gazojak
# Processing Record 26 of Set 10 | agaro
# Processing Record 27 of Set 10 | paita
# Processing Record 28 of Set 10 | mitzic
# Processing Record 29 of Set 10 | koppies
# Processing Record 30 of Set 10 | ballina
# Processing Record 31 of Set 10 | guaratingueta
# Processing Record 32 of Set 10 | lingyuan
# Processing Record 33 of Set 10 | aswan
# Processing Record 34 of Set 10 | umzimvubu
# umzimvubu not found, skipping...
# Processing Record 35 of Set 10 | shimizu
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | narsaq
# Processing Record 38 of Set 10 | zapolyarnyy
# Processing Record 39 of Set 10 | juruti
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | mandalgovi
# Processing Record 42 of Set 10 | tidore
# tidore not found, skipping...
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | harper
# Processing Record 45 of Set 10 | bertoua
# Processing Record 46 of Set 10 | yialos
# yialos not found, skipping...
# Processing Record 47 of Set 10 | kieta
# Processing Record 48 of Set 10 | zaysan
# Processing Record 49 of Set 10 | porto empedocle
# Processing Record 50 of Set 10 | bartica
# Processing Record 1 of Set 11 | koygorodok
# Processing Record 2 of Set 11 | kendari
# Processing Record 3 of Set 11 | tambura
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | placido de castro
# Processing Record 6 of Set 11 | phalaborwa
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | quelimane
# Processing Record 9 of Set 11 | obo
# Processing Record 10 of Set 11 | matagami
# Processing Record 11 of Set 11 | russell
# Processing Record 12 of Set 11 | pierre
# Processing Record 13 of Set 11 | jinchengjiang
# jinchengjiang not found, skipping...
# Processing Record 14 of Set 11 | waingapu
# Processing Record 15 of Set 11 | pafos
# Processing Record 16 of Set 11 | manokwari
# Processing Record 17 of Set 11 | paka
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | suntar
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | lappeenranta
# Processing Record 22 of Set 11 | broken hill
# Processing Record 23 of Set 11 | angul
# Processing Record 24 of Set 11 | bereda
# Processing Record 25 of Set 11 | eureka
# Processing Record 26 of Set 11 | piacabucu
# Processing Record 27 of Set 11 | pak phanang
# Processing Record 28 of Set 11 | nome
# Processing Record 29 of Set 11 | chiredzi
# Processing Record 30 of Set 11 | samana
# Processing Record 31 of Set 11 | malvern
# Processing Record 32 of Set 11 | sivagiri
# Processing Record 33 of Set 11 | gribanovskiy
# Processing Record 34 of Set 11 | katherine
# Processing Record 35 of Set 11 | nijar
# Processing Record 36 of Set 11 | zeya
# Processing Record 37 of Set 11 | snezhnogorsk
# Processing Record 38 of Set 11 | tilichiki
# Processing Record 39 of Set 11 | port-gentil
# Processing Record 40 of Set 11 | barcelos
# Processing Record 41 of Set 11 | ust-maya
# Processing Record 42 of Set 11 | gorele
# Processing Record 43 of Set 11 | roseburg
# Processing Record 44 of Set 11 | las palmas
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | west haven
# Processing Record 47 of Set 11 | yaan
# Processing Record 48 of Set 11 | hualmay
# Processing Record 49 of Set 11 | boyolangu
# Processing Record 50 of Set 11 | tyukhtet
# Processing Record 1 of Set 12 | teguldet
# Processing Record 2 of Set 12 | smirnykh
# Processing Record 3 of Set 12 | paso de carrasco
# Processing Record 4 of Set 12 | caravelas
# Processing Record 5 of Set 12 | viedma
# Processing Record 6 of Set 12 | brisbane
# Processing Record 7 of Set 12 | flin flon
# Processing Record 8 of Set 12 | qaqortoq
# Processing Record 9 of Set 12 | college
# Processing Record 10 of Set 12 | faya
# Processing Record 11 of Set 12 | jiayuguan
# Processing Record 12 of Set 12 | mount gambier
# Processing Record 13 of Set 12 | dom pedrito
# Processing Record 14 of Set 12 | along
# Processing Record 15 of Set 12 | ligayan
# Processing Record 16 of Set 12 | adrar
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | okhotsk
# Processing Record 19 of Set 12 | grand river south east
# grand river south east not found, skipping...
# Processing Record 20 of Set 12 | tahta
# Processing Record 21 of Set 12 | whyalla
# Processing Record 22 of Set 12 | shetpe
# Processing Record 23 of Set 12 | phulji
# Processing Record 24 of Set 12 | russellville
# Processing Record 25 of Set 12 | basco
# Processing Record 26 of Set 12 | hebertville
# hebertville not found, skipping...
# Processing Record 27 of Set 12 | okakarara
# Processing Record 28 of Set 12 | forest grove
# Processing Record 29 of Set 12 | ucluelet
# Processing Record 30 of Set 12 | carbonia
# Processing Record 31 of Set 12 | ramhormoz
# Processing Record 32 of Set 12 | bayanday
# Processing Record 33 of Set 12 | puerto gaitan
# Processing Record 34 of Set 12 | salinopolis
# Processing Record 35 of Set 12 | dimona
# Processing Record 36 of Set 12 | bandarbeyla
# Processing Record 37 of Set 12 | robertsport
# Processing Record 38 of Set 12 | toamasina
# Processing Record 39 of Set 12 | prince george
# Processing Record 40 of Set 12 | moussoro
# Processing Record 41 of Set 12 | siocon
# Processing Record 42 of Set 12 | garut
# Processing Record 43 of Set 12 | leningradskiy
# Processing Record 44 of Set 12 | beloha
# Processing Record 45 of Set 12 | la ronge
# Processing Record 46 of Set 12 | chifeng
# Processing Record 47 of Set 12 | sungaipenuh
# Processing Record 48 of Set 12 | progreso
# Processing Record 49 of Set 12 | lahaina
# Processing Record 50 of Set 12 | bakaly
# Processing Record 1 of Set 13 | craig
# Processing Record 2 of Set 13 | jumla
# Processing Record 3 of Set 13 | sao felix do xingu
# Processing Record 4 of Set 13 | husavik
# Processing Record 5 of Set 13 | camaqua
# Processing Record 6 of Set 13 | ostersund
# Processing Record 7 of Set 13 | gazni
# gazni not found, skipping...
# Processing Record 8 of Set 13 | andros town
# Processing Record 9 of Set 13 | uspenka
# Processing Record 10 of Set 13 | chapais
# Processing Record 11 of Set 13 | muros
# Processing Record 12 of Set 13 | tual
# Processing Record 13 of Set 13 | redcliffe
# Processing Record 14 of Set 13 | uaua
# Processing Record 15 of Set 13 | sosnovo
# Processing Record 16 of Set 13 | harlingen
# Processing Record 17 of Set 13 | saint-felix-de-valois
# Processing Record 18 of Set 13 | san cristobal
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | baculin
# Processing Record 21 of Set 13 | auki
# Processing Record 22 of Set 13 | toftir
# toftir not found, skipping...
# Processing Record 23 of Set 13 | otjimbingwe
# Processing Record 24 of Set 13 | ijaki
# ijaki not found, skipping...
# Processing Record 25 of Set 13 | ust-nera
# Processing Record 26 of Set 13 | djambala
# Processing Record 27 of Set 13 | moscow
# Processing Record 28 of Set 13 | cap malheureux
# Processing Record 29 of Set 13 | niamey
# Processing Record 30 of Set 13 | susanville
# Processing Record 31 of Set 13 | saint-francois
# Processing Record 32 of Set 13 | thayetmyo
# Processing Record 33 of Set 13 | batticaloa
# Processing Record 34 of Set 13 | valparaiso
# Processing Record 35 of Set 13 | gambela
# Processing Record 36 of Set 13 | ilhabela
# Processing Record 37 of Set 13 | attawapiskat
# attawapiskat not found, skipping...
# Processing Record 38 of Set 13 | mazamari
# Processing Record 39 of Set 13 | norrtalje
# Processing Record 40 of Set 13 | noyabrsk
# Processing Record 41 of Set 13 | tecoanapa
# Processing Record 42 of Set 13 | syracuse
# Processing Record 43 of Set 13 | vestmannaeyjar
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | kristiinankaupunki
# Processing Record 46 of Set 13 | cockburn town
# Processing Record 47 of Set 13 | westport
# Processing Record 48 of Set 13 | magnitogorsk
# Processing Record 49 of Set 13 | sola
# Processing Record 50 of Set 13 | barawe
# barawe not found, skipping...
# Processing Record 1 of Set 14 | terekli-mekteb
# Processing Record 2 of Set 14 | tucuman
# Processing Record 3 of Set 14 | khandyga
# Processing Record 4 of Set 14 | fort smith
# Processing Record 5 of Set 14 | manavgat
# Processing Record 6 of Set 14 | arroyo
# Processing Record 7 of Set 14 | qasigiannguit
# Processing Record 8 of Set 14 | escarcega
# Processing Record 9 of Set 14 | saint-leu
# Processing Record 10 of Set 14 | kisangani
# Processing Record 11 of Set 14 | san buenaventura
# Processing Record 12 of Set 14 | blagoyevo
# Processing Record 13 of Set 14 | gizo
# Processing Record 14 of Set 14 | roebourne
# Processing Record 15 of Set 14 | butterworth
# Processing Record 16 of Set 14 | hamilton
# Processing Record 17 of Set 14 | fort nelson
# Processing Record 18 of Set 14 | mikhaylovka
# Processing Record 19 of Set 14 | pacific grove
# Processing Record 20 of Set 14 | kushmurun
# Processing Record 21 of Set 14 | longyan
# Processing Record 22 of Set 14 | prenzlau
# Processing Record 23 of Set 14 | zakamensk
# Processing Record 24 of Set 14 | manali
# Processing Record 25 of Set 14 | douentza
# Processing Record 26 of Set 14 | chapada dos guimaraes
# Processing Record 27 of Set 14 | nago
# Processing Record 28 of Set 14 | port hawkesbury
# Processing Record 29 of Set 14 | douglas
# Processing Record 30 of Set 14 | bulungu
# Processing Record 31 of Set 14 | eyl
# Processing Record 32 of Set 14 | merauke
# Processing Record 33 of Set 14 | morondava
# Processing Record 34 of Set 14 | goderich
# Processing Record 35 of Set 14 | malm
# Processing Record 36 of Set 14 | turukhansk
# Processing Record 37 of Set 14 | sobolevo
# Processing Record 38 of Set 14 | tuggurt
# tuggurt not found, skipping...
# Processing Record 39 of Set 14 | karaul
# karaul not found, skipping...
# Processing Record 40 of Set 14 | drezdenko
# Processing Record 41 of Set 14 | buqayq
# buqayq not found, skipping...
# Processing Record 42 of Set 14 | plymouth
# Processing Record 43 of Set 14 | pangkalanbuun
# Processing Record 44 of Set 14 | yanchukan
# yanchukan not found, skipping...
# Processing Record 45 of Set 14 | havelock
# Processing Record 46 of Set 14 | barddhaman
# Processing Record 47 of Set 14 | hami
# Processing Record 48 of Set 14 | bolungarvik
# bolungarvik not found, skipping...
# Processing Record 49 of Set 14 | sorvag
# sorvag not found, skipping...
# Processing Record 50 of Set 14 | lamar
# Processing Record 1 of Set 15 | falealupo
# falealupo not found, skipping...
# Processing Record 2 of Set 15 | okrika
# Processing Record 3 of Set 15 | launceston
# Processing Record 4 of Set 15 | shache
# Processing Record 5 of Set 15 | pringsewu
# Processing Record 6 of Set 15 | waitati
# Processing Record 7 of Set 15 | gat
# Processing Record 8 of Set 15 | luebo
# Processing Record 9 of Set 15 | bacungan
# Processing Record 10 of Set 15 | teguise
# Processing Record 11 of Set 15 | saint anthony
# Processing Record 12 of Set 15 | henties bay
# Processing Record 13 of Set 15 | tura
# Processing Record 14 of Set 15 | dzaoudzi
# Processing Record 15 of Set 15 | todos santos
# Processing Record 16 of Set 15 | moree
# Processing Record 17 of Set 15 | ust-tsilma
# Processing Record 18 of Set 15 | ouesso
# Processing Record 19 of Set 15 | itoman
# Processing Record 20 of Set 15 | aberdeen
# Processing Record 21 of Set 15 | el faiyum
# el faiyum not found, skipping...
# Processing Record 22 of Set 15 | ponta delgada
# Processing Record 23 of Set 15 | atagay
# Processing Record 24 of Set 15 | lodja
# Processing Record 25 of Set 15 | parsabad
# Processing Record 26 of Set 15 | goya
# Processing Record 27 of Set 15 | houston
# Processing Record 28 of Set 15 | alim
# Processing Record 29 of Set 15 | poronaysk
# Processing Record 30 of Set 15 | morant bay
# Processing Record 31 of Set 15 | mtambile
# Processing Record 32 of Set 15 | altay
# Processing Record 33 of Set 15 | kizilskoye
# Processing Record 34 of Set 15 | wanaka
# Processing Record 35 of Set 15 | sao desiderio
# Processing Record 36 of Set 15 | antalaha
# Processing Record 37 of Set 15 | jalu
# Processing Record 38 of Set 15 | tumannyy
# tumannyy not found, skipping...
# Processing Record 39 of Set 15 | koratla
# Processing Record 40 of Set 15 | play cu
# play cu not found, skipping...
# Processing Record 41 of Set 15 | brae
# Processing Record 42 of Set 15 | kafanchan
# Processing Record 43 of Set 15 | umm lajj
# Processing Record 44 of Set 15 | pochutla
# Processing Record 45 of Set 15 | paramonga
# Processing Record 46 of Set 15 | bafq
# Processing Record 47 of Set 15 | achisay
# achisay not found, skipping...
# Processing Record 48 of Set 15 | inhambane
# Processing Record 49 of Set 15 | serov
# Processing Record 50 of Set 15 | nylstroom
# nylstroom not found, skipping...
# Processing Record 1 of Set 16 | helsinki
# Processing Record 2 of Set 16 | llangefni
# Processing Record 3 of Set 16 | lyngseidet
# Processing Record 4 of Set 16 | dunhua
# Processing Record 5 of Set 16 | venice
# Processing Record 6 of Set 16 | esmeraldas
# Processing Record 7 of Set 16 | karamay
# karamay not found, skipping...
# Processing Record 8 of Set 16 | esso
# Processing Record 9 of Set 16 | nova olimpia
# Processing Record 10 of Set 16 | klyuchi
# Processing Record 11 of Set 16 | sangar
# Processing Record 12 of Set 16 | laguna de perlas
# Processing Record 13 of Set 16 | torquay
# Processing Record 14 of Set 16 | skovorodino
# Processing Record 15 of Set 16 | ampanihy
# Processing Record 16 of Set 16 | alofi
# Processing Record 17 of Set 16 | hohhot
# Processing Record 18 of Set 16 | galgani
# galgani not found, skipping...
# Processing Record 19 of Set 16 | findlay
# Processing Record 20 of Set 16 | macusani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check how many successful data retrievals went through
len(city_data)
# Out:
# 718

# %%
# Convert the array of dictionaries to a Pandas Dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vardo  70.3705   31.1107     37.38        87          75
# 1       Georgetown   5.4112  100.3354     82.33        93          40
# 2   Gornopravdinsk  60.0500   69.9000     34.25        85         100
# 3           Atuona  -9.8000 -139.0333     79.00        71          29
# 4  Barra Do Garcas -15.8900  -52.2567     90.23        45          99
#
#    Wind Speed Country Current Description
# 0        9.22      NO       broken clouds
# 1        4.61      MY    scattered clouds
# 2        7.56      RU     overcast clouds
# 3       18.19      PF    scattered clouds
# 4        5.53      BR     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df [new_column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vardo      NO  70.3705   31.1107     37.38        87          75
# 1       Georgetown      MY   5.4112  100.3354     82.33        93          40
# 2   Gornopravdinsk      RU  60.0500   69.9000     34.25        85         100
# 3           Atuona      PF  -9.8000 -139.0333     79.00        71          29
# 4  Barra Do Garcas      BR -15.8900  -52.2567     90.23        45          99
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1        4.61    scattered clouds
# 2        7.56     overcast clouds
# 3       18.19    scattered clouds
# 4        5.53     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv", index=False)
